# %% [raw]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
# sns.set(style="ticks", color_codes=True)
# import os
# import re
# from datetime import datetime

# %%
os.chdir(r'C:\Users\pravi\Desktop\PGP-DSE\CAPSTONE\lt-vehicle-loan-default-prediction\GitHub\Data')

# %%
data_dict=pd.read_csv('./data_dictionary.csv')
data_dict
# Out:
#     Unnamed: 0                        Variable Name  \
# 0            0                             UniqueID
# 1            1                         loan_default
# 2            2                     disbursed_amount
# 3            3                           asset_cost
# 4            4                                  ltv
# 5            5                            branch_id
# 6            6                          supplier_id
# 7            7                      manufacturer_id
# 8            8                      Current_pincode
# 9            9                        Date.of.Birth
# 10          10                      Employment.Type
# 11          11                        DisbursalDate
# 12          12                             State_ID
# 13          13                     Employee_code_ID
# 14          14                    MobileNo_Avl_Flag
# 15          15                          Aadhar_flag
# 16          16                             PAN_flag
# ...

# %%
data_dict.dropna()
# Out:
#     Unnamed: 0    Variable Name  \
# 22          22  PRI.NO.OF.ACCTS
# 28          28  SEC.NO.OF.ACCTS
#
#                                           Description  \
# 22  count of total loans taken by the customer at ...
# 28  count of total loans taken by the customer at ...
#
#                                            Unnamed: 2
# 22  Primary accounts are those which the customer ...
# 28  Secondary accounts are those which the custome...

# %%
train=pd.read_csv('./train.csv')
train.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441      01-01-84        Salaried  ...
# 1               45                1502      31-07-85   Self employed  ...
# 2               45                1497      24-08-85   Self employed  ...
# 3               45                1501      30-12-93   Self employed  ...
# 4               45                1495      09-12-77   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
train.shape
# Out:
# (233154, 41)

# %%
test=pd.read_csv('./test.csv')
test.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    655269             53478       63558  86.54         67        22807
# 1    723482             55513       63163  89.45         67        22807
# 2    758529             65282       84320  79.93         78        23135
# 3    763449             46905       63896  76.58         78        17014
# 4    708663             51428       63896  86.08         78        17014
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1497      01-01-74        Salaried  ...
# 1               45                1497      20-05-85   Self employed  ...
# 2               86                2071      14-10-95        Salaried  ...
# 3               45                2070      01-06-73   Self employed  ...
# 4               45                2069      01-06-72        Salaried  ...
#
#   SEC.CURRENT.BALANCE  SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  \
# ...

# %%
test.shape
# Out:
# (112392, 40)

# %%
plt.figure(figsize=(30,20))
sns.heatmap(train.corr())

# %%
plt.figure(figsize=(40,30))
sns.heatmap(train.corr(),linewidths=0.05,annot=True)
plt.show()

# %%
train.columns
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default'],
#       dtype='object')

# %%
import missingno

# %%
missingno.matrix(train,figsize=(20,20))

# %%
missingno.matrix(test,figsize=(20,20))

# %%
train.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441      01-01-84        Salaried  ...
# 1               45                1502      31-07-85   Self employed  ...
# 2               45                1497      24-08-85   Self employed  ...
# 3               45                1501      30-12-93   Self employed  ...
# 4               45                1495      09-12-77   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
train.describe()
# Out:
#             UniqueID  disbursed_amount    asset_cost            ltv  \
# count  233154.000000     233154.000000  2.331540e+05  233154.000000
# mean   535917.573376      54356.993528  7.586507e+04      74.746530
# std     68315.693711      12971.314171  1.894478e+04      11.456636
# min    417428.000000      13320.000000  3.700000e+04      10.030000
# 25%    476786.250000      47145.000000  6.571700e+04      68.880000
# 50%    535978.500000      53803.000000  7.094600e+04      76.800000
# 75%    595039.750000      60413.000000  7.920175e+04      83.670000
# max    671084.000000     990572.000000  1.628992e+06      95.000000
#
#            branch_id    supplier_id  manufacturer_id  Current_pincode_ID  \
# count  233154.000000  233154.000000    233154.000000       233154.000000
# mean       72.936094   19638.635035        69.028054         3396.880247
# std        69.834995    3491.949566        22.141304         2238.147502
# ...

# %%
train.dtypes
# Out:
# UniqueID                                 int64
# disbursed_amount                         int64
# asset_cost                               int64
# ltv                                    float64
# branch_id                                int64
# supplier_id                              int64
# manufacturer_id                          int64
# Current_pincode_ID                       int64
# Date.of.Birth                           object
# Employment.Type                         object
# DisbursalDate                           object
# State_ID                                 int64
# Employee_code_ID                         int64
# MobileNo_Avl_Flag                        int64
# Aadhar_flag                              int64
# PAN_flag                                 int64
# VoterID_flag                             int64
# Driving_flag                             int64
# Passport_flag                            int64
# PERFORM_CNS.SCORE                        int64
# ...

# %%
# Since 'MobileNo_Avl_Flag' has 0 variance. dropping this feature
UniqueID=[test.UniqueID]
train.drop(['UniqueID','MobileNo_Avl_Flag'],axis=1,inplace=True)
test.drop(['UniqueID','MobileNo_Avl_Flag'],axis=1,inplace=True)

# %%
# Setting up time marker

d_marker= '21-04-19'
def days_between(d1, d2):
    d1 = datetime.strptime(d1, "%d-%m-%y")
    d2 = datetime.strptime(d2, "%d-%m-%y")
    return abs((d2 - d1).days)

# %%
# age as on 1-1-2019 (in yrs)
train['Date.of.Birth'] = train['Date.of.Birth'].apply(lambda x:  days_between(x,d_marker)/365)
# Calculating time (in yrs) after disbursal
train['DisbursalDate']= train['DisbursalDate'].apply(lambda x:  days_between(x,d_marker)/365)
# age as on 1-1-2019 (in yrs)
test['Date.of.Birth'] = test['Date.of.Birth'].apply(lambda x:  days_between(x,d_marker)/365)
# Calculating time (in yrs) after disbursal
test['DisbursalDate']= test['DisbursalDate'].apply(lambda x:  days_between(x,d_marker)/365)

# %%
# Converting the given 'CREDIT HISTORY LENGTH' in months
train['CREDIT.HISTORY.LENGTH']=train['CREDIT.HISTORY.LENGTH'].apply(lambda x:
                                                                   (re.sub('[a-z]','',x)).split())
train['CREDIT.HISTORY.LENGTH']=train['CREDIT.HISTORY.LENGTH'].apply(lambda x:
                                                                   int(x[0])*12+int(x[1]))

test['CREDIT.HISTORY.LENGTH']=test['CREDIT.HISTORY.LENGTH'].apply(lambda x:
                                                                   (re.sub('[a-z]','',x)).split())
test['CREDIT.HISTORY.LENGTH']=test['CREDIT.HISTORY.LENGTH'].apply(lambda x:
                                                                   int(x[0])*12+int(x[1]))
# Converting the given 'AVERAGE ACC AGE ' om months
train['AVERAGE.ACCT.AGE']=train['AVERAGE.ACCT.AGE'].apply(lambda x:(re.sub('[a-z]','',x)).split())
train['AVERAGE.ACCT.AGE']=train['AVERAGE.ACCT.AGE'].apply(lambda x:int(x[0])*12+int(x[1]))

test['AVERAGE.ACCT.AGE']=test['AVERAGE.ACCT.AGE'].apply(lambda x:(re.sub('[a-z]','',x)).split())
test['AVERAGE.ACCT.AGE']=test['AVERAGE.ACCT.AGE'].apply(lambda x:int(x[0])*12+int(x[1]))

# %%
ct_col= ['branch_id','supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Employment.Type', 'State_ID', 'Employee_code_ID', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag','Driving_flag', 'Passport_flag','PERFORM_CNS.SCORE.DESCRIPTION']


con_col= ['disbursed_amount', 'asset_cost', 'ltv','Date.of.Birth','DisbursalDate', 'PERFORM_CNS.SCORE', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
       'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
       'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
       'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
       'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
       'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
       'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES']

# %%
train[ct_col].head()
# Out:
#    branch_id  supplier_id  manufacturer_id  Current_pincode_ID  \
# 0         67        22807               45                1441
# 1         67        22807               45                1502
# 2         67        22807               45                1497
# 3         67        22807               45                1501
# 4         67        22807               45                1495
#
#   Employment.Type  State_ID  Employee_code_ID  Aadhar_flag  PAN_flag  \
# 0        Salaried         6              1998            1         0
# 1   Self employed         6              1998            1         0
# 2   Self employed         6              1998            1         0
# 3   Self employed         6              1998            1         0
# 4   Self employed         6              1998            1         0
#
#    VoterID_flag  Driving_flag  Passport_flag PERFORM_CNS.SCORE.DESCRIPTION
# 0             0             0              0   No Bureau History Available
# ...

# %%
train[con_col]
# Out:
#         disbursed_amount  asset_cost    ltv  Date.of.Birth  DisbursalDate  \
# 0                  50578       58400  89.55      35.326027       0.715068
# 1                  47145       65550  73.23      33.745205       0.567123
# 2                  53278       61360  89.63      33.679452       0.720548
# 3                  57513       66113  88.48      25.323288       0.484932
# 4                  52378       60300  88.39      41.391781       0.567123
# ...                  ...         ...    ...            ...            ...
# 233149             63213      105405  60.72      30.739726       0.484932
# 233150             73651      100600  74.95      30.394521       0.493151
# 233151             33484       71212  48.45      42.915068       0.490411
# 233152             34259       73286  49.10      25.087671       0.558904
# 233153             75751      116009  66.81      35.194521       0.482192
#
#         PERFORM_CNS.SCORE  PRI.NO.OF.ACCTS  PRI.ACTIVE.ACCTS  \
# ...

# %% [markdown]
# ## Missing Values

# %%
train.isnull().sum()
# Out:
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# PRI.NO.OF.ACCTS                           0
# PRI.ACTIVE.ACCTS                          0
# ...

# %%
train['Employment.Type'].value_counts()
# Out:
# Self employed    127635
# Salaried          97858
# Name: Employment.Type, dtype: int64

# %%
print('Percentage of missing values is {0}% for the training set'.format(round(100*train['Employment.Type'].isnull().sum()/len(train),2)))
print('Percentage of missing values is {0}% for the test set'.format(round(100*test['Employment.Type'].isnull().sum()/len(train),2)))
# Out:
# Percentage of missing values is 3.29% for the training set
# Percentage of missing values is 1.48% for the test set

# %%
# Substituting the null values by third category 'unknown'
train.fillna('unknown', inplace=True)
test.fillna('unknown', inplace=True)
train['Employment.Type'].value_counts()
# Out:
# Self employed    127635
# Salaried          97858
# unknown            7661
# Name: Employment.Type, dtype: int64

# %%
pd.concat([train.isnull().sum(),test.isnull().sum()], sort= False, axis=1)
# Out:
#                                      0    1
# disbursed_amount                     0  0.0
# asset_cost                           0  0.0
# ltv                                  0  0.0
# branch_id                            0  0.0
# supplier_id                          0  0.0
# manufacturer_id                      0  0.0
# Current_pincode_ID                   0  0.0
# Date.of.Birth                        0  0.0
# Employment.Type                      0  0.0
# DisbursalDate                        0  0.0
# State_ID                             0  0.0
# Employee_code_ID                     0  0.0
# Aadhar_flag                          0  0.0
# PAN_flag                             0  0.0
# VoterID_flag                         0  0.0
# Driving_flag                         0  0.0
# Passport_flag                        0  0.0
# PERFORM_CNS.SCORE                    0  0.0
# PERFORM_CNS.SCORE.DESCRIPTION        0  0.0
# PRI.NO.OF.ACCTS                      0  0.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
train.iloc[:,8]=le.fit_transform(train.iloc[:,8])
train.iloc[:,18]=le.fit_transform(train.iloc[:,18])
test.iloc[:,8]=le.fit_transform(test.iloc[:,8])
test.iloc[:,18]=le.fit_transform(test.iloc[:,18])

# %%
pd.set_option('display.max_columns', 500)

# %%
train
# Out:
#         disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0                  50578       58400  89.55         67        22807
# 1                  47145       65550  73.23         67        22807
# 2                  53278       61360  89.63         67        22807
# 3                  57513       66113  88.48         67        22807
# 4                  52378       60300  88.39         67        22807
# ...                  ...         ...    ...        ...          ...
# 233149             63213      105405  60.72         34        20700
# 233150             73651      100600  74.95         34        23775
# 233151             33484       71212  48.45         77        22186
# 233152             34259       73286  49.10         77        22186
# 233153             75751      116009  66.81         77        22186
#
#         manufacturer_id  Current_pincode_ID  Date.of.Birth  Employment.Type  \
# ...

# %% [markdown]
# ### disbursed_amount

# %%
sns.distplot(train['disbursed_amount'])

# %%
sns.boxplot(train['disbursed_amount'])

# %%
sns.boxplot(train[train['disbursed_amount']<190_000]['disbursed_amount'])

# %%
#ie=train[train['disbursed_amount']>190_000].index
#print(ie)

# %%
# train.loc[ie,'disbursed_amount']=np.nan

# %%
train.isnull().sum()
# Out:
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# Current_pincode_ID                     0
# Date.of.Birth                          0
# Employment.Type                        0
# DisbursalDate                          0
# State_ID                               0
# Employee_code_ID                       0
# Aadhar_flag                            0
# PAN_flag                               0
# VoterID_flag                           0
# Driving_flag                           0
# Passport_flag                          0
# PERFORM_CNS.SCORE                      0
# PERFORM_CNS.SCORE.DESCRIPTION          0
# PRI.NO.OF.ACCTS                        0
# PRI.ACTIVE.ACCTS                       0
# PRI.OVERDUE.ACCTS                      0
# PRI.CURRENT.BALANCE                    0
# ...

# %%
'''from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer(max_iter=10, random_state=0)'''
# Out:
# 'from sklearn.impute import KNNImputer\nfrom sklearn.experimental import enable_iterative_imputer\nfrom sklearn.impute import IterativeImputer\nimp = IterativeImputer(max_iter=10, random_state=0)'

# %%
# pd.DataFrame(imp.fit_transform(train))

# %% [markdown]
# ### asset_cost

# %%
train
# Out:
#         disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0                  50578       58400  89.55         67        22807
# 1                  47145       65550  73.23         67        22807
# 2                  53278       61360  89.63         67        22807
# 3                  57513       66113  88.48         67        22807
# 4                  52378       60300  88.39         67        22807
# ...                  ...         ...    ...        ...          ...
# 233149             63213      105405  60.72         34        20700
# 233150             73651      100600  74.95         34        23775
# 233151             33484       71212  48.45         77        22186
# 233152             34259       73286  49.10         77        22186
# 233153             75751      116009  66.81         77        22186
#
#         manufacturer_id  Current_pincode_ID  Date.of.Birth  Employment.Type  \
# ...

# %%
sns.boxplot(train['asset_cost'])

# %%
train[train['asset_cost']==train['asset_cost'].max()]
# Out:
#         disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 210252            990572     1628992  61.39        138        24062
#
#         manufacturer_id  Current_pincode_ID  Date.of.Birth  Employment.Type  \
# 210252              152                3368      28.865753                2
#
#         DisbursalDate  State_ID  Employee_code_ID  Aadhar_flag  PAN_flag  \
# 210252       0.679452         9              2934            1         1
#
#         VoterID_flag  Driving_flag  Passport_flag  PERFORM_CNS.SCORE  \
# 210252             0             0              0                 16
#
#         PERFORM_CNS.SCORE.DESCRIPTION  PRI.NO.OF.ACCTS  PRI.ACTIVE.ACCTS  \
# 210252                             15                1                 0
#
#         PRI.OVERDUE.ACCTS  PRI.CURRENT.BALANCE  PRI.SANCTIONED.AMOUNT  \
# 210252                  1                    0                      0
#
#         PRI.DISBURSED.AMOUNT  SEC.NO.OF.ACCTS  SEC.ACTIVE.ACCTS  \
# ...

# %%
sns.boxplot(train[(train['asset_cost']<87_000)&(train['asset_cost']>52_000)]['asset_cost'])

# %% [markdown]
# ### itv

# %%
 sns.boxplot(train['ltv'])

# %% [markdown]
# ### supplier_id

# %%
train['supplier_id'].value_counts()
# Out:
# 18317    1432
# 15694    1300
# 15663    1275
# 17980    1268
# 14234    1258
#          ...
# 22811       1
# 23189       1
# 23712       1
# 15045       1
# 18019       1
# Name: supplier_id, Length: 2953, dtype: int64

# %%
supplier_loan=pd.crosstab(train['supplier_id'],train['loan_default'])

# %%
import  scipy.stats                     as  stats

# %%
chi_sq, p_value, deg_freedom, exp_freq = stats.chi2_contingency(supplier_loan)
print('Chi Square Statistics',chi_sq)
print('p-value',p_value)
print('Degree of freedom',deg_freedom)
p_value
# Out:
# Chi Square Statistics 9339.709281561767
# p-value 0.0
# Degree of freedom 2952
# 0.0

# %%
train=train.drop(['supplier_id'],axis=1)
test=test.drop(['supplier_id'],axis=1)

# %% [markdown]
# ### branch_id

# %%
train['branch_id'].value_counts()
# Out:
# 2      13138
# 67     11328
# 3       9230
# 5       9218
# 36      8832
#        ...
# 217      183
# 261      176
# 84       156
# 111       89
# 158       69
# Name: branch_id, Length: 82, dtype: int64

# %%
pd.crosstab(train['branch_id'],train['loan_default'])
# Out:
# loan_default      0     1
# branch_id
# 1              4856   853
# 2             10683  2455
# 3              7616  1614
# 5              7171  2047
# 7              2566   656
# ...             ...   ...
# 257            1007   249
# 258             297    77
# 259             267    79
# 260             274    98
# 261             137    39
#
# [82 rows x 2 columns]

# %%
chi_sq, p_value, deg_freedom, exp_freq = stats.chi2_contingency(supplier_loan)
print('Chi Square Statistics',chi_sq)
print('p-value',p_value)
print('Degree of freedom',deg_freedom)
# Out:
# Chi Square Statistics 9339.709281561767
# p-value 0.0
# Degree of freedom 2952

# %%
train=train.drop(['branch_id'],axis=1)
test=test.drop(['branch_id'],axis=1)

# %% [markdown]
# ### manufacture_id

# %%
train['manufacturer_id'].value_counts()
# Out:
# 86     109534
# 45      56626
# 51      27204
# 48      16710
# 49      10220
# 120      9658
# 67       2405
# 145       778
# 153        12
# 152         6
# 156         1
# Name: manufacturer_id, dtype: int64

# %%
manu_loan=pd.crosstab(train['manufacturer_id'],train['loan_default'])
print(manu_loan)
# Out:
# loan_default         0      1
# manufacturer_id
# 45               43687  12939
# 48               12156   4554
# 49                7984   2236
# 51               21547   5657
# 67                1882    523
# 86               87124  22410
# 120               7526   2132
# 145                622    156
# 152                  6      0
# 153                  8      4
# 156                  1      0

# %%
chi_sq, p_value, deg_freedom, exp_freq = stats.chi2_contingency(manu_loan)
print('Chi Square Statistics',chi_sq)
print('p-value',p_value)
print('Degree of freedom',deg_freedom)
# Out:
# Chi Square Statistics 464.69764016358414
# p-value 1.5277380091688753e-93
# Degree of freedom 10

# %% [markdown]
# ### Date.of.Birth
# Changed to **Age**

# %%
train.rename(columns={'Date.of.Birth':'Age'},inplace=True)
test.rename(columns={'Date.of.Birth':'Age'},inplace=True)

# %%
train.head()
# Out:
#    disbursed_amount  asset_cost    ltv  manufacturer_id  Current_pincode_ID  \
# 0             50578       58400  89.55               45                1441
# 1             47145       65550  73.23               45                1502
# 2             53278       61360  89.63               45                1497
# 3             57513       66113  88.48               45                1501
# 4             52378       60300  88.39               45                1495
#
#          Age  Employment.Type  DisbursalDate  State_ID  Employee_code_ID  \
# 0  35.326027                0       0.715068         6              1998
# 1  33.745205                1       0.567123         6              1998
# 2  33.679452                1       0.720548         6              1998
# 3  25.323288                1       0.484932         6              1998
# 4  41.391781                1       0.567123         6              1998
#
# ...

# %% [markdown]
# ### Employment Type

# %%
train['Employment.Type'].value_counts()
# Out:
# 1    127635
# 0     97858
# 2      7661
# Name: Employment.Type, dtype: int64

# %%
train['Employment.Type'].value_counts().plot(kind='bar')

# %%
emp_loan=pd.crosstab(train['Employment.Type'],train['loan_default'])
print(emp_loan)
# Out:
# loan_default         0      1
# Employment.Type
# 0                77948  19910
# 1                98578  29057
# 2                 6017   1644

# %%
chi_sq, p_value, deg_freedom, exp_freq = stats.chi2_contingency(emp_loan)
print('Chi Square Statistics',chi_sq)
print('p-value',p_value)
print('Degree of freedom',deg_freedom)
# Out:
# Chi Square Statistics 191.1398528340361
# p-value 3.1225422343284505e-42
# Degree of freedom 2

# %% [markdown]
# ### DisbursalDate

# %%
sns.distplot(train['DisbursalDate'])

# %% [markdown]
# ### StateId

# %%
train['State_ID'].value_counts()
# Out:
# 4     44870
# 3     34078
# 6     33505
# 13    17884
# 9     16022
# 8     14197
# 5     10177
# 14     9414
# 1      8936
# 7      6786
# 11     6721
# 18     5412
# 15     5049
# 12     4210
# 2      4160
# 17     3991
# 10     3605
# 16     2685
# 19     1035
# 20      185
# 21      156
# 22       76
# Name: State_ID, dtype: int64

# %%
state_loan=pd.crosstab(train['State_ID'],train['loan_default'])
print(state_loan)
# Out:
# loan_default      0     1
# State_ID
# 1              7353  1583
# 2              3031  1129
# 3             27733  6345
# 4             35544  9326
# 5              8154  2023
# 6             26615  6890
# 7              5417  1369
# 8             10939  3258
# 9             12530  3492
# 10             2972   633
# 11             5348  1373
# 12             3092  1118
# 13            12401  5483
# 14             6817  2597
# 15             3981  1068
# 16             2192   493
# 17             3010   981
# 18             4221  1191
# 19              848   187
# 20              153    32
# 21              125    31
# 22               67     9

# %%
chi_sq, p_value, deg_freedom, exp_freq = stats.chi2_contingency(state_loan)
print('Chi Square Statistics',chi_sq)
print('p-value',p_value)
print('Degree of freedom',deg_freedom)
# Out:
# Chi Square Statistics 1626.8617814468685
# p-value 0.0
# Degree of freedom 21

# %% [markdown]
# ### State_ID: Passport_flag

# %%
train.loc[:,'State_ID':'Passport_flag']
# Out:
#         State_ID  Employee_code_ID  Aadhar_flag  PAN_flag  VoterID_flag  \
# 0              6              1998            1         0             0
# 1              6              1998            1         0             0
# 2              6              1998            1         0             0
# 3              6              1998            1         0             0
# 4              6              1998            1         0             0
# ...          ...               ...          ...       ...           ...
# 233149         6              3705            0         0             1
# 233150         6              3705            0         0             1
# 233151         4              3479            1         0             0
# 233152         4              3479            1         0             0
# 233153         4              3479            1         0             0
#
#         Driving_flag  Passport_flag
# 0                  0              0
# ...

# %%
temp=train.loc[:,'State_ID':'Passport_flag'].columns
print(temp)
# Out:
# Index(['State_ID', 'Employee_code_ID', 'Aadhar_flag', 'PAN_flag',
#        'VoterID_flag', 'Driving_flag', 'Passport_flag'],
#       dtype='object')

# %%
for i in temp:
    print('Feature:',i)
    chi_sq, p_value, deg_freedom, exp_freq = stats.chi2_contingency(pd.crosstab(train[i],train['loan_default']))
    print('Chi Square Statistics',chi_sq)
    print('p-value',p_value)
    print('Degree of freedom',deg_freedom)
    print()
# Out:
# Feature: State_ID
# Chi Square Statistics 1626.8617814468685
# p-value 0.0
# Degree of freedom 21
#
# Feature: Employee_code_ID
# Chi Square Statistics 10531.308446989955
# p-value 0.0
# Degree of freedom 3269
#
# Feature: Aadhar_flag
# Chi Square Statistics 403.0748379341479
# p-value 1.1791998402218374e-89
# Degree of freedom 1
#
# Feature: PAN_flag
# Chi Square Statistics 0.957671117865875
# p-value 0.3277743362589148
# Degree of freedom 1
#
# Feature: VoterID_flag
# Chi Square Statistics 445.90884255981064
# p-value 5.603683381655361e-99
# Degree of freedom 1
#
# Feature: Driving_flag
# Chi Square Statistics 7.808087835127649
# p-value 0.0052012912081583085
# Degree of freedom 1
#
# Feature: Passport_flag
# Chi Square Statistics 13.077913022819462
# p-value 0.0002987981770071958
# Degree of freedom 1

# %%
train=train.drop(['State_ID','Employee_code_ID','PAN_flag'],axis=1)
test=test.drop(['State_ID','Employee_code_ID','PAN_flag'],axis=1)

# %%
train.columns
# Out:
# Index(['disbursed_amount', 'asset_cost', 'ltv', 'manufacturer_id',
#        'Current_pincode_ID', 'Age', 'Employment.Type', 'DisbursalDate',
#        'Aadhar_flag', 'VoterID_flag', 'Driving_flag', 'Passport_flag',
#        'PERFORM_CNS.SCORE', 'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS',
#        'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE',
#        'PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS',
#        'SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE',
#        'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT',
#        'SEC.INSTAL.AMT', 'NEW.ACCTS.IN.LAST.SIX.MONTHS',
#        'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 'AVERAGE.ACCT.AGE',
#        'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES', 'loan_default'],
#       dtype='object')

# %% [markdown]
# ### 'PERFORM_CNS.SCORE', 'PERFORM_CNS.SCORE.DESCRIPTION'

# %%
train[['PERFORM_CNS.SCORE', 'PERFORM_CNS.SCORE.DESCRIPTION']]
# Out:
#         PERFORM_CNS.SCORE  PERFORM_CNS.SCORE.DESCRIPTION
# 0                       0                             13
# 1                     598                              8
# 2                       0                             13
# 3                     305                             11
# 4                       0                             13
# ...                   ...                            ...
# 233149                735                              3
# 233150                825                              0
# 233151                  0                             13
# 233152                  0                             13
# 233153                  0                             13
#
# [233154 rows x 2 columns]

# %%
train[ 'PERFORM_CNS.SCORE.DESCRIPTION'].value_counts()
# Out:
# 13    116950
# 2      16045
# 0      14124
# 3      11358
# 1       9201
# 12      8776
# 5       8485
# 10      8277
# 7       6855
# 4       5821
# 8       5557
# 6       3988
# 19      3765
# 9       3748
# 17      3672
# 15      2885
# 16      1534
# 11      1134
# 18       976
# 14         3
# Name: PERFORM_CNS.SCORE.DESCRIPTION, dtype: int64

# %%
train[ 'PERFORM_CNS.SCORE'].value_counts()
# Out:
# 0      116950
# 300      8776
# 738      8662
# 825      7393
# 15       3765
#         ...
# 838         1
# 862         1
# 822         1
# 847         1
# 867         1
# Name: PERFORM_CNS.SCORE, Length: 573, dtype: int64

# %% [markdown]
# ### 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE','PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT'

# %%
train.loc[:,[ 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE','PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT']]
# Out:
#         PRI.NO.OF.ACCTS  PRI.ACTIVE.ACCTS  PRI.OVERDUE.ACCTS  \
# 0                     0                 0                  0
# 1                     1                 1                  1
# 2                     0                 0                  0
# 3                     3                 0                  0
# 4                     0                 0                  0
# ...                 ...               ...                ...
# 233149                4                 3                  0
# 233150                1                 0                  0
# 233151                0                 0                  0
# 233152                0                 0                  0
# 233153                0                 0                  0
#
#         PRI.CURRENT.BALANCE  PRI.SANCTIONED.AMOUNT  PRI.DISBURSED.AMOUNT
# 0                         0                      0                     0
# 1                     27600                  50200                 50200
# ...

# %%
primary=train.loc[:,[ 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE','PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT']]

# %%
primary.describe()
# Out:
#        PRI.NO.OF.ACCTS  PRI.ACTIVE.ACCTS  PRI.OVERDUE.ACCTS  \
# count    233154.000000     233154.000000      233154.000000
# mean          2.440636          1.039896           0.156549
# std           5.217233          1.941496           0.548787
# min           0.000000          0.000000           0.000000
# 25%           0.000000          0.000000           0.000000
# 50%           0.000000          0.000000           0.000000
# 75%           3.000000          1.000000           0.000000
# max         453.000000        144.000000          25.000000
#
#        PRI.CURRENT.BALANCE  PRI.SANCTIONED.AMOUNT  PRI.DISBURSED.AMOUNT
# count         2.331540e+05           2.331540e+05          2.331540e+05
# mean          1.659001e+05           2.185039e+05          2.180659e+05
# std           9.422736e+05           2.374794e+06          2.377744e+06
# min          -6.678296e+06           0.000000e+00          0.000000e+00
# ...

# %%
primary['PRI.NO.OF.ACCTS'].value_counts()
# Out:
# 0      116950
# 1       34978
# 2       19784
# 3       13015
# 4        9323
#         ...
# 83          1
# 147         1
# 120         1
# 194         1
# 124         1
# Name: PRI.NO.OF.ACCTS, Length: 108, dtype: int64

# %% [markdown]
# ### 'SEC.NO.OF.ACCTS','SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE','SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT'

# %%
train[['SEC.NO.OF.ACCTS',
       'SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE',
       'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT']]
# Out:
#         SEC.NO.OF.ACCTS  SEC.ACTIVE.ACCTS  SEC.OVERDUE.ACCTS  \
# 0                     0                 0                  0
# 1                     0                 0                  0
# 2                     0                 0                  0
# 3                     0                 0                  0
# 4                     0                 0                  0
# ...                 ...               ...                ...
# 233149                0                 0                  0
# 233150                0                 0                  0
# 233151                0                 0                  0
# 233152                0                 0                  0
# 233153                0                 0                  0
#
#         SEC.CURRENT.BALANCE  SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT
# 0                         0                      0                     0
# 1                         0                      0                     0
# ...

# %%
secondary=train[['SEC.NO.OF.ACCTS',
       'SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE',
       'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT']]

# %%
secondary['SEC.NO.OF.ACCTS'].value_counts()
# Out:
# 0     227289
# 1       3466
# 2       1036
# 3        444
# 4        292
# 5        148
# 6        119
# 7         75
# 8         68
# 9         38
# 10        35
# 11        29
# 13        17
# 12        13
# 16        11
# 14        11
# 15        10
# 18         6
# 19         6
# 17         5
# 20         4
# 22         4
# 23         4
# 31         4
# 21         3
# 46         2
# 24         2
# 38         2
# 30         2
# 34         2
# 37         1
# 42         1
# 28         1
# 35         1
# 29         1
# 25         1
# 52         1
# Name: SEC.NO.OF.ACCTS, dtype: int64

# %%
secondary.describe()
# Out:
#        SEC.NO.OF.ACCTS  SEC.ACTIVE.ACCTS  SEC.OVERDUE.ACCTS  \
# count    233154.000000     233154.000000      233154.000000
# mean          0.059081          0.027703           0.007244
# std           0.626795          0.316057           0.111079
# min           0.000000          0.000000           0.000000
# 25%           0.000000          0.000000           0.000000
# 50%           0.000000          0.000000           0.000000
# 75%           0.000000          0.000000           0.000000
# max          52.000000         36.000000           8.000000
#
#        SEC.CURRENT.BALANCE  SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT
# count         2.331540e+05           2.331540e+05          2.331540e+05
# mean          5.427793e+03           7.295923e+03          7.179998e+03
# std           1.702370e+05           1.831560e+05          1.825925e+05
# min          -5.746470e+05           0.000000e+00          0.000000e+00
# ...

# %% [markdown]
# ### PRIMARY.INSTAL.AMT

# %%
train.columns
# Out:
# Index(['disbursed_amount', 'asset_cost', 'ltv', 'manufacturer_id',
#        'Current_pincode_ID', 'Age', 'Employment.Type', 'DisbursalDate',
#        'Aadhar_flag', 'VoterID_flag', 'Driving_flag', 'Passport_flag',
#        'PERFORM_CNS.SCORE', 'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS',
#        'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE',
#        'PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS',
#        'SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE',
#        'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT',
#        'SEC.INSTAL.AMT', 'NEW.ACCTS.IN.LAST.SIX.MONTHS',
#        'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 'AVERAGE.ACCT.AGE',
#        'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES', 'loan_default'],
#       dtype='object')

# %%
train['PRIMARY.INSTAL.AMT']
# Out:
# 0            0
# 1         1991
# 2            0
# 3           31
# 4            0
#           ...
# 233149    4084
# 233150    1565
# 233151       0
# 233152       0
# 233153       0
# Name: PRIMARY.INSTAL.AMT, Length: 233154, dtype: int64

# %%
sns.boxplot(train['PRIMARY.INSTAL.AMT'])

# %% [markdown]
# ### SEC.INSTAL.AMT

# %%
train['SEC.INSTAL.AMT']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 233149    0
# 233150    0
# 233151    0
# 233152    0
# 233153    0
# Name: SEC.INSTAL.AMT, Length: 233154, dtype: int64

# %%
train['SEC.INSTAL.AMT'].value_counts()
# Out:
# 0         230937
# 2100           7
# 1100           6
# 5000           6
# 1065           6
#            ...
# 1744           1
# 6098           1
# 2256           1
# 108900         1
# 16695          1
# Name: SEC.INSTAL.AMT, Length: 1918, dtype: int64

# %% [markdown]
# ### NEW.ACCTS.IN.LAST.SIX.MONTHS

# %%
train['NEW.ACCTS.IN.LAST.SIX.MONTHS']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 233149    0
# 233150    0
# 233151    0
# 233152    0
# 233153    0
# Name: NEW.ACCTS.IN.LAST.SIX.MONTHS, Length: 233154, dtype: int64

# %%
train['NEW.ACCTS.IN.LAST.SIX.MONTHS'].value_counts()
# Out:
# 0     181494
# 1      32099
# 2      11015
# 3       4458
# 4       1957
# 5        964
# 6        480
# 7        302
# 8        147
# 9         79
# 10        55
# 11        31
# 12        20
# 13        15
# 14        11
# 16         6
# 17         6
# 20         3
# 15         2
# 18         2
# 19         2
# 23         2
# 28         1
# 21         1
# 22         1
# 35         1
# Name: NEW.ACCTS.IN.LAST.SIX.MONTHS, dtype: int64

# %% [markdown]
# ### DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS

# %%
train['NEW.ACCTS.IN.LAST.SIX.MONTHS']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 233149    0
# 233150    0
# 233151    0
# 233152    0
# 233153    0
# Name: NEW.ACCTS.IN.LAST.SIX.MONTHS, Length: 233154, dtype: int64

# %% [markdown]
# ### DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS

# %%
train['DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS']
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 233149    0
# 233150    0
# 233151    0
# 233152    0
# 233153    0
# Name: DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS, Length: 233154, dtype: int64

# %%
train['DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS'].value_counts()
# Out:
# 0     214959
# 1      14941
# 2       2470
# 3        537
# 4        138
# 5         58
# 6         20
# 7         13
# 8          7
# 12         3
# 11         3
# 10         2
# 9          2
# 20         1
# Name: DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS, dtype: int64

# %% [markdown]
# ### AVERAGE.ACCT.AGE

# %%
train['AVERAGE.ACCT.AGE'].index
# Out:
# RangeIndex(start=0, stop=233154, step=1)

# %% [markdown]
# ### CREDIT.HISTORY.LENGTH

# %%
train['CREDIT.HISTORY.LENGTH'].index
# Out:
# RangeIndex(start=0, stop=233154, step=1)

# %%
train.columns
# Out:
# Index(['disbursed_amount', 'asset_cost', 'ltv', 'manufacturer_id',
#        'Current_pincode_ID', 'Age', 'Employment.Type', 'DisbursalDate',
#        'Aadhar_flag', 'VoterID_flag', 'Driving_flag', 'Passport_flag',
#        'PERFORM_CNS.SCORE', 'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS',
#        'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE',
#        'PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS',
#        'SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE',
#        'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT',
#        'SEC.INSTAL.AMT', 'NEW.ACCTS.IN.LAST.SIX.MONTHS',
#        'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 'AVERAGE.ACCT.AGE',
#        'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES', 'loan_default'],
#       dtype='object')

# %% [markdown]
# ### NO.OF_INQUIRIES

# %%
train['NO.OF_INQUIRIES'].value_counts()
# Out:
# 0     201961
# 1      22285
# 2       5409
# 3       1767
# 4        760
# 5        343
# 6        239
# 7        135
# 8        105
# 9         44
# 10        34
# 11        15
# 12        14
# 14         8
# 15         7
# 13         6
# 19         6
# 17         4
# 18         4
# 16         3
# 28         1
# 20         1
# 22         1
# 23         1
# 36         1
# Name: NO.OF_INQUIRIES, dtype: int64

# %%
train['NO.OF_INQUIRIES'].describe()
# Out:
# count    233154.000000
# mean          0.206615
# std           0.706498
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          36.000000
# Name: NO.OF_INQUIRIES, dtype: float64

# %% [markdown]
# ### loan_default (Target/Dependent Variable)

# %%
print(train['loan_default'].value_counts())
sns.countplot(train['loan_default'])
# Out:
# 0    182543
# 1     50611
# Name: loan_default, dtype: int64

# %% [markdown]
# ## Base Model

# %%
y=train.loan_default
X=train.drop("loan_default",axis=1)
from sklearn.model_selection import train_test_split,KFold,cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)
# Out:
# C:\Users\pravi\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# for Test set
model_score = lr.score(X_test,y_test)
print(model_score)
# Out:
# 0.7827783893519379

# %%
# for train set
model_score = lr.score(X_train,y_train)
print(model_score)
# Out:
# 0.7829566133805536

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report

# %%
print("precision :",precision_score(y_test,y_pred),"\n")
print("f1 score:",f1_score(y_test,y_pred),"\n")
# Out:
# precision : 0.0
#
# f1 score: 0.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88     54756
#            1       0.00      0.00      0.00     15191
#
#     accuracy                           0.78     69947
#    macro avg       0.39      0.50      0.44     69947
# weighted avg       0.61      0.78      0.69     69947

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[54753,     3],
#        [15191,     0]], dtype=int64)

# %% [markdown]
# ## With Scaling

# %%
numerical = ['disbursed_amount','asset_cost','ltv','PRI.CURRENT.BALANCE','PRI.SANCTIONED.AMOUNT',
             'PRI.DISBURSED.AMOUNT','SEC.CURRENT.BALANCE','SEC.SANCTIONED.AMOUNT','SEC.DISBURSED.AMOUNT',
             'PRIMARY.INSTAL.AMT','SEC.INSTAL.AMT']

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
lr=LogisticRegression()
lr.fit(X_train[numerical],y_train)
y_pred=lr.predict(X_test)
# Out:
# C:\Users\pravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-134-c30976686f06> in <module>
#       1 lr=LogisticRegression()
# ----> 2 lr.fit(X_train[numerical],y_train)
#       3 y_pred=lr.predict(X_test)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# for Test set
model_score = lr.score(X_test,y_test)
print(model_score)
# Out:
# 0.7824638654981629

# %%
model_score = lr.score(X_train,y_train)
print(model_score)
# Out:
# 0.7826931442891543

# %%
print("precision :",precision_score(y_test,y_pred),"\n")
print("f1 score:",f1_score(y_test,y_pred),"\n")
# Out:
# precision : 0.42138364779874216
#
# f1 score: 0.008729641693811074

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[54664,    92],
#        [15124,    67]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88     54756
#            1       0.42      0.00      0.01     15191
#
#     accuracy                           0.78     69947
#    macro avg       0.60      0.50      0.44     69947
# weighted avg       0.70      0.78      0.69     69947

# %% [markdown]
# ### Robust Scaler

# %%
y=train.loan_default
X=train.drop("loan_default",axis=1)
from sklearn.model_selection import train_test_split,KFold,cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()

# %%
X_train=rs.fit_transform(X_train)
X_test=rs.transform(X_test)

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)
# Out:
# C:\Users\pravi\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# for Test set
model_score = lr.score(X_test,y_test)
print(model_score)
# Out:
# 0.782749796274322

# %%
model_score = lr.score(X_train,y_train)
print(model_score)
# Out:
# 0.7829198502515211

# %%
print("precision :",precision_score(y_test,y_pred),"\n")
print("f1 score:",f1_score(y_test,y_pred),"\n")
# Out:
# precision : 0.14285714285714285
#
# f1 score: 0.0001315962626661403

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[54750,     6],
#        [15190,     1]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88     54756
#            1       0.14      0.00      0.00     15191
#
#     accuracy                           0.78     69947
#    macro avg       0.46      0.50      0.44     69947
# weighted avg       0.64      0.78      0.69     69947
